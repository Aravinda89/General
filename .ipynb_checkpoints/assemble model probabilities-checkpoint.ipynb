# %%
import pandas as pd

# %%
ls
# Out:
# $RECYCLE.BIN/
# +Long+Short-Term+Memory+Networks+(LSTMs)+Subtitles.zip
# +Long+Short-Term+Memory+Networks+(LSTMs)+Videos.zip
# 11645-12309-1-PB.pdf
# 12039125_10208733248354959_4278297796841772305_o.jpg
# 2. Baysian Thinking Notes.pptx
# 20131205170922786250.jpg
# 2301903-gp (1).jpg
# 2301903-gp.jpg
# 2_43.mp4
# 4kvideodownloader_4.9.1.dmg
# 720p.h264.mp4
# 960x0.jpg
# 9781461414322-c1.pdf
# AIND-CV-FacialKeypoints-master/
# AI部2020年2月3日工作日志_加阳.xlsx
# AI部2020年2月4日工作日志_加阳.xlsx
# AI部分产品开发规划(1).xlsx
# Abhishek learned to apply deep learning concepts to self-driving cars.mp4
# Advanced+CNN+Architectures+Subtitles.zip
# Advanced+CNN+Architectures+Videos.zip
# Aerial-Cactus-Identification_submission (1).csv
# Aerial-Cactus-Identification_submission.csv
# Alex_Self-driving/
# An intro to self-driving cars with David Silver.mp4
# Andrew_NG_ML/
# Announcing the C   Nanodegree Program! Learn C   to code the world's most exciting tech.mp4
# Aravinda_Gayan_resume_ENG_FINALFF.docx
# Blue Screen.ipynb
# Bucky  C++/
# Bucky Linux/
# C   Nanodegree Program Open House.mp4
# CE_company_culture.pdf
# CVND-udacity-master/
# Cat_Dog_data.zip*
# Chapter 6 - Deploying a DNN model on low power edge devices.pdf
# Chinese HSK 5 week 1 lesson 1 (1).mp4
# Chinese HSK 5 week 1 lesson 1 (2).mp4
# Chinese HSK 5 week 1 lesson 1 (3).mp4
# Chinese HSK 5 week 1 lesson 1.mp4
# Chinese HSK 5 week 1 lesson 2.mp4
# Chinese HSK 5 week 1 lesson 3.mp4
# Chinese HSK 5 week 1 lesson 4.mp4
# Chinese HSK 5 week 1 lesson 5.mp4
# Chinese HSK 5 week 2 lesson 10.mp4
# Chinese HSK 5 week 2 lesson 6.mp4
# Chinese HSK 5 week 2 lesson 7.mp4
# Chinese HSK 5 week 2 lesson 8.mp4
# Chinese HSK 5 week 2 lesson 9.mp4
# Chinese HSK 5 week 3 lesson 11.mp4
# Chinese HSK 5 week 3 lesson 12.mp4
# Chinese HSK 5 week 3 lesson 13.mp4
# Chinese HSK 5 week 3 lesson 14.mp4
# Chinese HSK 5 week 3 lesson 15.mp4
# Chinese HSK 5 week 4 lesson 16.mp4
# Chinese HSK 5 week 4 lesson 17.mp4
# Chinese HSK 5 week 4 lesson 18.mp4
# Chinese HSK 5 week 4 lesson 19.mp4
# Chinese HSK 5 week 4 lesson 20.mp4
# Chinese HSK 5 week 5 lesson 22.mp4
# Chinese HSK 5 week 5 lesson 23 (1).mp4
# Chinese HSK 5 week 5 lesson 23.mp4
# Chinese HSK 5 week 5 lesson 24.mp4
# Chinese HSK 5 week 5 lesson 25.mp4
# Chinese HSK 5 week 6 lesson 26.mp4
# Chinese HSK 5 week 6 lesson 27.mp4
# Chinese HSK 5 week 6 lesson 28.mp4
# Chinese HSK 5 week 6 lesson 29.mp4
# Chinese HSK 5 week 6 lesson 30.mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Adjectives 1 to 30 (34_43).mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Adjectives 31 to 60 (35_43).mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Adjectives 61 to 90 (36_43).mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Adjectives 91 to 120 (37_43).mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 361 to 390 (32_43).mp4
# Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 391 to 428 (33_43).mp4
# Chinese car claim image classification standard.docx
# Cities of the Future - Interactive, Responsive, and Optimized.mp4
# CourseClub.Me-Udacity - Intro to Self-Driving Cars v1.0.0.torrent
# DC to Edge Course/
# DingTalk_v4.7.25.6.dmg
# Facial-Keypoint-Detection-master/
# Facial-Keypoint-Detection-master-2/
# Facial-Keypoint-Detection-master.zip.download/
# Facial_Keypoints-master.zip.download/
# Firefox 65.0.dmg
# FlySmiLes_v1.6_apkpure.com.apk
# From College to Starting a Career in Self-Driving Cars.mp4
# GPG-PUB-KEY-INTEL-OPENVINO-2020
# George Hotz Presents Comma Neo for Udacity Students.mp4
# GitHub Desktop.app/
# GitHubDesktop.zip
# HSK 5 Course - Chinese Vocabulary Course - HSK 5 Full Course _ Adjectives 121 to 150 (38_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course - Nouns 241 to 270 _ (9_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course - Nouns 271 to 300 _ (10_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ (15_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Adverbs 1 to 30 (40_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Conjunctions (42_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 1 to 30 (1_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 151 - 180 (6_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 181 to 210 (7_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 211 to 240 (8_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 301 to 330 (11_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 331 to 360 (12_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 361 to 390 (13_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 391 to 420 (14_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 451 to 480 (16_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 481 to 510 (17_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 511 to 540 (18_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 541 to 575 (19_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 61 to 90 (3_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Nouns 91 to 120 (4_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Remaining Words (43_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 1 to 30 (20_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 181 to 210 (26_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 241 to 270 (28_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 271 to 300 (29_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 31 to 60 (21_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 331 to 360 (31_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 61 to 90 (22_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course _ Verbs 91 to 120 (23_43).mp4
# HSK 5 Course - Complete Chinese Vocabulary Course - HSK 5 Full Course- Adjectives 151 to 181 (39_43).mp4
# HSK 5 week 5 lesson 21.mp4
# Hear from the first team to successfully run their code on Udacity's self-driving car.mp4
# Hyperparameters+Subtitles.zip
# Hyperparameters+Videos.zip
# Image+Captioning+Subtitles.zip
# Image+Captioning+Videos.zip
# Improve+Your+Online+Presence+Using+LinkedIn+Subtitles.zip
# Improve+Your+Online+Presence+Using+LinkedIn+Videos.zip
# Intel-Movidius-v01-Class6.zip
# Learn Chinese HSK 5 Vocabulary with Pinyin .mp4
# Learn Chinese HSK 5 Vocabulary with Pinyin and English Sentence Examples - Verbs 121 to 150 (24_43).mp4
# Learn Chinese HSK 5 Vocabulary with Pinyin and English Sentence Examples - Verbs 151 to 180 (25_43).mp4
# Learn Chinese HSK 5 Vocabulary with Pinyin and English Sentence Examples - Verbs 211 to 240 (27_43).mp4
# Learn Chinese HSK 5 Vocabulary with Pinyin and English Sentence Examples - Verbs 301 to 330 (30_43).mp4
# List_eng.xlsx
# MX-3118NC_20180629_114414-rotated.pdf
# Machine Learning in the Google Self-Driving Car.mp4
# ManyCam.dmg
# ManyCam_v4.0.52.exe
# Mercedes-Benz R.mp4
# Miniconda3-latest-MacOSX-x86_64.pkg
# NVIDIA Shares What They Look For in Hiring for the Autonomous Vehicles Division.mp4
# NVIDIA talks about its supercomputers in self-driving cars.mp4
# New to self-driving cars.mp4
# On the Road to Building the Self-Driving Car Engineer Nanodegree Program.mp4
# Optional_+Attention+Mechanisms+Subtitles.zip
# Optional_+Attention+Mechanisms+Videos.zip
# PCV/
# Parasite.2019.1080p.BluRay.1600MB.DD5.1.x264-GalaxyRG[TGx]/
# Parasite.2019.1080p.BluRay.x265.MeGaTroN/
# Parasite.2019.1080p.BluRay.x265.MeGaTroN.torrent*
# Plant_Pathology_2020.ipynb
# Plant_Pathology_2020_densenet201_0.0001_2020-04-08--15-47.json
# Plant_Pathology_2020_densenet201_0.0001_Epoch08_2020-04-06--14-47.hdf5
# Plant_Pathology_2020_densenet201_1e-05_2020-04-11--10-38.json
# Plant_Pathology_2020_densenet201_1e-05_2020-04-11--10-39.hdf5
# Plant_Pathology_2020_densenet201_1e-05_Epoch01_2020-04-08--16-18.hdf5
# Playing Guitar in MIT Autonomous Vehicle (Driver Activity Recognition).mp4.download/
# Preparing dataset for custom YOLO v3 object detector.mp4
# Psiphon Pro The Internet Freedom VPN_v214_apkpure.com.apk
# RNN's+Subtitles.zip
# RNN's+Videos.zip
# Sebastian Thrun and Danny Shapiro Q.mp4
# Sebastian Thrun talks about the Self-Driving Car Engineer Nanodegree program and the industry.mp4
# Self-Driving Car Fundamentals_ Featuring Baidu Apollo.mp4
# ShadowsocksX-NG.app/
# Shortcuts-for-Data-Scientists-2020.pdf
# Sn.xlsx
# Standford_FeiFei_Li/
# Start on the Road to a Self-Driving Car Career (1).mp4
# Start on the road to a self-driving car career.mp4
# Statically Typed (1).zip
# Statically Typed.zip
# Sublime Text Build 3207.dmg
# TensorFlow YOLO v3 Tutorial example.mp4
# Testing YOLO v3 CSGO Keras aimbot.mp4
# The Self-Driving Car Engineer Nanodegree Capstone Project.mp4
# The Self-Driving Hour with David Silver and Anthony Navarro.mp4
# The.Grand.Tour.S03E10.720p.WEB.H264-AMCON[rartv].torrent*
# This Udacity grad learned with a global community to master self-driving cars.mp4
# Thumbs.db
# Training custom YOLO v3 object detector with Keras.mp4
# Udacity - Intro to Self-Driving Cars Nanodegree.torrent
# Udacity Talks Episode 12_ Sebastian Thrun on Autonomous Transportation.mp4
# What is the Self-Driving Car Engineer Nanodegree Program.mp4
# Why should you consider a career in self-driving cars.mp4
# XX部2020年2月XX日工作日志(1).xlsx
# YOLO+Subtitles.zip
# YOLO+Videos (1).zip
# YOLO+Videos.zip
# ai--facial-keypoints-detection-cnn-master/
# applsci-08-01575 (1).pdf
# applsci-08-01575.pdf
# arxiv_data/
# arxiv_data.zip
# å??äº?å??é??ç?¥.docx
# caj2pdf-master/
# car-damage-dataset.tar
# cars_annos.mat
# cars_test.tgz*
# cats_dogs_classifier_densenet201_1e-05_Epoch02_2020-03-15--12-54.hdf5
# certificate.pdf
# cifar-10-python.tar.gz
# com.hschinese.hellowords_2016-11-06.apk
# company_culture.docx
# company_culture.pdf
# d8fad85aa9c4768ff401efc5ea1a1317237a4ae5.torrent*
# dc_to_the_edge (1).zip
# ddownr.zip
# ddownr1/
# dog-png-with-pride.png
# download (1).jpeg
# download.jpeg
# environment_16.yml
# facial-keypoint-detection-master-3/
# inception_v1.ckpt
# inception_v1_2016_08_28.tar
# inception_v4_299_quant_20181026/
# inception_v4_299_quant_20181026.tgz
# ipython_notebook_tutorial.ipynb
# jbxxShowzp.jsp.jpeg
# libarchive-3.3.3-h786848e_5.tar.bz2
# main 2.cpp*
# main.cpp*
# make-01-00036.pdf
# makkama.pdf
# metadata.csv
# metadata.csv.zip
# metadata2.csv
# new_om_application_formK (1).pdf
# new_om_application_formK.pdf
# organize.docx
# person-vehicle-bike-detection-crossroad-0078.xml
# project3.zip
# rar/
# rar 2/
# rar 3/
# rarosx-5.7.1.tar.gz
# showthread.html
# skype-2-9256410 (1).html
# skype-2-9256410.html
# submission (1).csv
# submission (2).csv
# submission.csv
# submission_10.csv
# submission_11_4_2020.csv
# submission_2.csv
# submission_3.csv
# submission_4.csv
# submission_7.csv
# submission_8.csv
# submission_9.csv
# the_ceylon_princess_of_quanzhou_iC6qg58SqQ0_144p.mp4
# the_ceylon_princess_of_quanzhou_iC6qg58SqQ0_360p.mp4
# thunder_3.3.9.4280.dmg
# train.zip
# train_hq/
# train_hq.zip
# train_masks.csv
# train_masks.csv.zip
# viber-12-7-0-6.apk
# vott-2.1.0-darwin.dmg
# webwxgetmsgimg-2.jpeg
# webwxgetmsgimg-3.jpeg
# webwxgetmsgimg.jpeg
# wwwwwwwwwwwwwwwwwwwww.caj
# y2mate.com - the_ceylon_princess_of_quanzhou_iC6qg58SqQ0_240p.mp4
# zip (1).zip
# ~$AI部分产品开发规划(1).xlsx
# 委+托+书.pdf
# 工作证明 (1).pdf
# 个人简历-王宪（中文）0818.docx
# 个人简历-王宪（英文）0818.docx
# 工作证明.pdf
# 合同盖章页.pdf
# 申请表盖章页.pdf
# 网上办理承诺书.pdf
# 出入境申请表盖章页.pdf
# 外国人签证证件申请表-1.pdf

# %%
df1 = pd.read_csv('submission (1).csv')
df1.head()
# Out:
#   image_id       healthy  multiple_diseases          rust          scab
# 0   Test_0  5.086713e-05       1.230842e-03  9.996755e-01  1.045056e-05
# 1   Test_1  4.817591e-06       3.997725e-04  9.998621e-01  3.039982e-07
# 2   Test_2  2.738178e-07       6.594482e-06  1.792853e-07  9.999995e-01
# 3   Test_3  1.000000e+00       6.314535e-10  7.958223e-07  3.045144e-08
# 4   Test_4  2.704071e-06       1.777140e-05  9.999923e-01  3.749147e-07

# %%
df2 = pd.read_csv('submission_9.csv')
df2.head()
# Out:
#   image_id   healthy  multiple_diseases      rust      scab
# 0   Test_0  0.001125           0.200496  0.973705  0.002685
# 1   Test_1  0.000412           0.120691  0.967122  0.006936
# 2   Test_2  0.000170           0.003437  0.000319  0.999627
# 3   Test_3  0.999995           0.000027  0.000346  0.000094
# 4   Test_4  0.000038           0.000952  0.999901  0.000063

# %%
df_asem_1 = pd.DataFrame(columns=['image_id','healthy','multiple_diseases','rust','scab'])
df_asem_1['image_id']=df1['image_id']
df_asem_1
# Out:
#        image_id healthy multiple_diseases rust scab
# 0        Test_0     NaN               NaN  NaN  NaN
# 1        Test_1     NaN               NaN  NaN  NaN
# 2        Test_2     NaN               NaN  NaN  NaN
# 3        Test_3     NaN               NaN  NaN  NaN
# 4        Test_4     NaN               NaN  NaN  NaN
# ...         ...     ...               ...  ...  ...
# 1816  Test_1816     NaN               NaN  NaN  NaN
# 1817  Test_1817     NaN               NaN  NaN  NaN
# 1818  Test_1818     NaN               NaN  NaN  NaN
# 1819  Test_1819     NaN               NaN  NaN  NaN
# 1820  Test_1820     NaN               NaN  NaN  NaN
#
# [1821 rows x 5 columns]

# %%
df2.iloc[:,1:]*0.5 + df1.iloc[:,1:]*0.5
# Out:
#        healthy  multiple_diseases      rust      scab
# 0     0.000588           0.100863  0.986690  0.001348
# 1     0.000208           0.060545  0.983492  0.003468
# 2     0.000085           0.001722  0.000160  0.999813
# 3     0.999998           0.000013  0.000173  0.000047
# 4     0.000021           0.000485  0.999946  0.000032
# ...        ...                ...       ...       ...
# 1816  0.000715           0.002921  0.994356  0.000264
# 1817  0.001333           0.371102  0.011200  0.284255
# 1818  0.000199           0.000539  0.999702  0.000328
# 1819  0.999579           0.000107  0.000646  0.000308
# 1820  0.018206           0.155524  0.014807  0.819355
#
# [1821 rows x 4 columns]
